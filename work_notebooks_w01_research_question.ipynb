# %% [markdown]
# <a href="https://colab.research.google.com/github/Marwan77770/Marwan_FlyRank/blob/main/work_notebooks_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Marwan77770/Marwan_FlyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1.My lane: Refresh / Content Opportunity Scoring
#
# I chose this lane because the starter dataset contains observable search, content, and engagement signals that can help identify pages that may deserve review. The goal is not to automatically decide that a page should be changed, but to prioritize which pages a human reviewer should examine first for possible refresh, expansion, protection, pruning, or monitoring. This makes the project a decision-support problem rather than simply a model-training task.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Research question: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring based on their observed search and engagement signals?
#
# Decision: Decide which pages should receive priority for human content review.
#
# Action: A content or search team member can review the highest-priority pages and decide whether to refresh, expand, protect, prune, or monitor them.
#
# Unit of analysis: One content page in the starter dataset, identified by its content/page identifier.
#
# Output: A ranked review queue of pages, with a priority score and evidence/reason codes that explain why each page was prioritized.
#
# Cost of a wrong recommendation: A false positive could waste the team's limited time and resources on a page that does not need attention. A false negative could cause a potentially important page to be overlooked. Therefore, the ranking should support human review rather than automatically determine the final action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 content pages. All 30,000 pages have recorded impressions and sessions, providing observable search and engagement signals for prioritization. In addition, 16,262 pages show a declining trend, suggesting that there is a substantial set of pages that may be worth reviewing for potential refresh or other content actions. These numbers make Refresh / Content Opportunity Scoring a useful direction to investigate further over the next seven weeks.

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.shape)
# Out:
# Rows: 30000
# Columns: 44
# (30000, 44)

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("Pages with impressions:", (df["impressions_90d"] > 0).sum())
print("Pages with sessions:", (df["sessions_90d"] > 0).sum())
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Rows: 30000
# Columns: 44
# Pages with impressions: 30000
# Pages with sessions: 30000
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# areful words: what I can and can't claim
#
# What I can claim:
#
# The dataset contains observable search, content, and engagement signals for content pages.
# These signals can be used to rank pages for human review.
# A scoring or ranking model can help prioritize limited review capacity.
# The current analysis can identify associations between observed signals and the proxy outcome in the dataset.
#
# What I can't claim:
#
# I cannot claim that the model proves that a specific signal causes a page's performance to decline.
# I cannot claim that the model predicts Google rankings or search-engine behavior directly.
# I cannot claim that a high-priority page will definitely improve after being refreshed.
# I cannot treat the current trend_direction label as a guaranteed future outcome; it is a proxy based on the current observation window.
# The model should support human decision-making rather than automatically deciding which action must be taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# Self-check
#
# I chose a clear lane.
#
# I defined a decision and an action.
#
# I identified the unit of analysis.
#
# I defined the expected output.
#
# I included real numbers from the starter dataset.
#
# I explained the cost of wrong recommendations.
#
# I explained why data and machine learning can help.
#
# I avoided causal claims and unsupported predictions.
#
# I positioned the model as decision support rather than an automatic decision-maker.
